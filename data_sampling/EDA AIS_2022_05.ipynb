# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt = pd.read_csv("AIS_MMSI_sampled.csv")
df = pd.DataFrame(dt)

# %%
display(df.head(5))
# Out:
#         MMSI         BaseDateTime       LAT        LON  SOG    COG  Heading  \
# 0  368061000  2022-05-22T00:00:01  29.58393  -89.09923  0.0   56.7     53.0
# 1  316005713  2022-05-22T00:00:05  49.29760 -123.02928  0.1  166.7    511.0
# 2  367357110  2022-05-22T00:00:01  39.08448  -81.76003  0.0  105.5    511.0
# 3  367781550  2022-05-22T00:00:02  41.40401  -88.21831  5.4   22.4     17.0
# 4  368731000  2022-05-22T00:00:00  36.88328  -76.35181  0.0    0.0    511.0
#
#         VesselName         IMO CallSign  VesselType  Status  Length  Width  \
# 0        C-CLIPPER  IMO9132167  WCX6887        90.0     0.0    67.0   17.0
# 1    PACIFIC FORCE         NaN      NaN        52.0     0.0    14.0    7.0
# 2   PERE MARQUETTE         NaN  WDE4728        31.0    12.0    42.0   10.0
# 3  GARLAND GASPARD         NaN  WDJ4830        31.0    12.0     NaN    NaN
# 4    CG FRANK DREW  IMO9177258     NKDL        90.0     5.0    53.0   10.0
#
#    Draft  Cargo TransceiverClass
# ...

# %%
df.corr()
# Out:
#                 MMSI       LAT       LON       SOG       COG   Heading  \
# MMSI        1.000000 -0.102967  0.022859  0.089088 -0.010591 -0.113437
# LAT        -0.102967  1.000000 -0.312242 -0.038440  0.009069  0.074182
# LON         0.022859 -0.312242  1.000000  0.011095 -0.005655  0.018826
# SOG         0.089088 -0.038440  0.011095  1.000000 -0.095753 -0.148753
# COG        -0.010591  0.009069 -0.005655 -0.095753  1.000000  0.234484
# Heading    -0.113437  0.074182  0.018826 -0.148753  0.234484  1.000000
# VesselType  0.169871 -0.059064  0.018449  0.165555 -0.085596 -0.344354
# Status     -0.046152 -0.057805  0.057332 -0.151945 -0.009360  0.032414
# Length      0.237759 -0.061925  0.002196  0.245148 -0.128719 -0.456061
# Width       0.299873 -0.128398  0.024442  0.240298 -0.126528 -0.481270
# Draft       0.266397 -0.092200 -0.019022  0.293717 -0.108529 -0.383654
# Cargo       0.143596 -0.073945  0.042859  0.156336 -0.004119 -0.247987
#
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
print(df.isnull().sum())
# Out:
# MMSI                      0
# BaseDateTime              0
# LAT                       0
# LON                       0
# SOG                       0
# COG                       0
# Heading                   0
# VesselName             7898
# IMO                 5275620
# CallSign            1242106
# VesselType            38904
# Status              3005730
# Length               779135
# Width               2133881
# Draft               7561886
# Cargo               3003843
# TransceiverClass          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11467262 entries, 0 to 11467261
# Data columns (total 17 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   MMSI              int64
#  1   BaseDateTime      object
#  2   LAT               float64
#  3   LON               float64
#  4   SOG               float64
#  5   COG               float64
#  6   Heading           float64
#  7   VesselName        object
#  8   IMO               object
#  9   CallSign          object
#  10  VesselType        float64
#  11  Status            float64
#  12  Length            float64
#  13  Width             float64
#  14  Draft             float64
#  15  Cargo             float64
#  16  TransceiverClass  object
# dtypes: float64(11), int64(1), object(5)
# memory usage: 1.5+ GB

# %%
df.describe()
# Out:
#                MMSI           LAT           LON           SOG           COG  \
# count  1.146726e+07  1.146726e+07  1.146726e+07  1.146726e+07  1.146726e+07
# mean   3.682990e+08  3.459855e+01 -9.247216e+01  2.335788e+00  2.135200e+02
# std    5.725086e+07  7.285451e+00  1.804600e+01  5.238736e+00  1.156540e+02
# min    3.183130e+07  8.693140e+00 -1.764733e+02  0.000000e+00  0.000000e+00
# 25%    3.669591e+08  2.953724e+01 -9.512490e+01  0.000000e+00  1.175000e+02
# 50%    3.675138e+08  3.272609e+01 -8.938812e+01  0.000000e+00  2.339000e+02
# 75%    3.680610e+08  3.989382e+01 -8.012560e+01  2.800000e+00  3.167000e+02
# max    9.831921e+08  7.585307e+01  1.451497e+02  1.023000e+02  4.012000e+02
#
#             Heading    VesselType        Status        Length         Width  \
# count  1.146726e+07  1.142836e+07  8.461532e+06  1.068813e+07  9.333381e+06
# mean   3.600508e+02  4.558093e+01  4.217191e+00  5.740354e+01  1.198116e+01
# ...

# %%
df.boxplot(column=['COG','Heading', 'VesselType'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Status','Width','Draft'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['LAT', 'LON','Cargo'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Length'])
# Out:
# <AxesSubplot:>

# %%
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

geometry = [Point(xy) for xy in zip(df['LON'], df['LAT'])]
gdf = GeoDataFrame(df, geometry=geometry)   

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(20, 20)), marker='.', color='red', markersize=5)
# Out:
# <AxesSubplot:>
